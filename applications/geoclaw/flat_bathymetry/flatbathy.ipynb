# %% [markdown]
# # Flat bathymetry
#
# ---
#
# Example of plane wave on flat bathymetry.
#
#
# ---

# %% [markdown]
# Create topography files and data files

# %%
# %run make_topo.py

# %%
# %run make_data.py

# %% [markdown]
# Run code in **serial mode** (will work, even if code is compiled with MPI)

# %%
# !flatbathy
# Out:
# [libsc] This is libsc 2.0.5-2d03
# [libsc] CPP                      mpicc -E
# [libsc] CPPFLAGS
# [libsc] CC                       mpicc
# [libsc] CFLAGS                   -O2 -Wall -DNETCDF -lnetcdf
# [libsc] LDFLAGS
# [libsc] LIBS                     -lgomp
# [libsc] Shared memory node communicator size: 1
# [p4est] This is p4est 2.0.21-5772
# [p4est] CPP                      mpicc -E
# [p4est] CPPFLAGS
# [p4est] CC                       mpicc
# [p4est] CFLAGS                   -O2 -Wall -DNETCDF -lnetcdf
# [p4est] LDFLAGS
# [p4est] LIBS                     -lgomp
# [fclaw] This is ForestClaw 0.1.3630-0e0da-dirty
# [fclaw] CPP                      mpicc -E
# [fclaw] CPPFLAGS
# [fclaw] F77                      mpif77
# [fclaw] FFLAGS                   -O2 -cpp
# [fclaw] CC                       mpicc
# [fclaw] CFLAGS                   -O2 -Wall -DNETCDF -lnetcdf
# [fclaw] CXX                      mpicxx
# [fclaw] CXXFLAGS                 -O2 -Wall
# [fclaw] LDFLAGS
# ...

# %% [markdown]
# ---
# Or, run code in **parallel mode** (command may need to be customized, depending your on MPI installation.)

# %%
#!mpirun -n 4 flatbathy

# %% [markdown]
# ---
# Create PNG files needed to visualize output in web browser, or to create animations (below).

# %%
# %run make_plots.py

# %% [markdown]
# ---
# View PNG files in at URL above,  or create an animation of all PNG files, using code below.

# %%
# %pylab inline

# %%
import glob
from matplotlib import image
from clawpack.visclaw.JSAnimation import IPython_display
from matplotlib import animation

def init():
    im.set_data(image.imread(filenames[0]))
    return im,

def animate(i):
    image_i=image.imread(filenames[i])
    im.set_data(image_i)
    return im,

# %% [markdown]
# ---
# Plot figure 0, showing the entire solution.  To see detailed plotting parameters, see file make_plots.py.

# %%
figno = 0

fname = '_plots/*fig' + str(figno) + '.png'
filenames = sorted(glob.glob(fname))

fig = plt.figure()
im = plt.imshow(image.imread(filenames[0]))

animation.FuncAnimation(fig, animate, init_func=init,
                              frames=len(filenames), interval=500, blit=True)

# %% [markdown]
# ---
