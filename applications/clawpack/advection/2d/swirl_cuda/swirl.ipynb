# %% [markdown]
# # Swirl
#
# ---
#
# Scalar advection problem with swirling velocity field.
#
# ---

# %% [markdown]
# Run code in **serial mode** (will work, even if code is compiled with MPI)

# %%
# !swirl

# %% [markdown]
# ---
# Or, run code in **parallel mode** (command may need to be customized, depending your on MPI installation.)

# %%
# !mpirun -n 4 swirl
# Out:
# [libsc] This is libsc 2.0.5-2d03
# [libsc] CPP                      mpicxx -E
# [libsc] CPPFLAGS
# [libsc] CC                       mpicxx
# [libsc] CFLAGS                   -Wall -O2
# [libsc] [libsc] This is libsc 2.0.5-2d03
# [libsc] CPP                      mpicxx -E
# [libsc] CPPFLAGS
# [libsc] CC                       mpicxx
# [libsc] CFLAGS                   -Wall -O2
# [libsc] LDFLAGS
# [libsc] LIBS                     -lgomp   -lz
# [libsc] This is libsc 2.0.5-2d03
# [libsc] CPP                      mpicxx -E
# [libsc] CPPFLAGS
# [libsc] CC                       mpicxx
# [libsc] CFLAGS                   -Wall -O2
# [libsc] LDFLAGS
# [libsc] LIBS                     -lgomp   -lz
# [libsc] This is libsc 2.0.5-2d03
# [libsc] CPP                      mpicxx -E
# [libsc] CPPFLAGS
# [libsc] CC                       mpicxx
# [libsc] CFLAGS                   -Wall -O2
# [libsc] LDFLAGS
# [libsc] LIBS                     -lgomp   -lz
# LDFLAGS
# [libsc] LIBS                     -lgomp   -lz
# [libsc] Shared memory node communicator size: 1
# [libsc] Shared memory node communicator size: 1
# [libsc] Shared memory node communicator size: 1
# [libsc] Shared memory node communicator size: 1
# [p4est] This is p4est 2.0.21-5772
# [p4est] CPP                      mpicxx -E
# [p4est] [p4est] This is p4est 2.0.21-5772
# [p4est] CPP                      mpicxx -E
# CPPFLAGS
# [p4est] CC                       mpicxx
# [p4est] CFLAGS                   -Wall -O2
# [p4est] LDFLAGS
# [p4est] This is p4est 2.0.21-5772
# [p4est] CPP                      mpicxx -E
# [p4est] CPPFLAGS
# [p4est] CC                       mpicxx
# [p4est] CFLAGS                   -Wall -O2
# [p4est[p4est] CPPFLAGS
# [p4est] CC                       mpicxx
# [p4est] CFLAGS                   -Wall -O2
# [p4est] LDFLAGS
# [p4est] [p4est] This is p4est 2.0.21-5772
# [p4est] CPP                      mpicxx -E
# [p4est] CPPFLAGS
# [p4est] LIBS                     -lgomp   -lz
# [fclaw] This is ForestClaw 0.1.3876-132c8e-dirty
# [fclaw] CPP                      mpicxx -E
# [fclaw] CPPFLAGS
# [fclaw] F77                      mpif77
# [fclaw] FFLAGS                   -O2
# [fclaw] CC                       mpicxx
# [] LDFLAGS
# [p4est] LIBS                     -lgomp   -lz
# [fclaw] This is ForestClaw 0.1.3876-132c8e-dirty
# [fclaw] CPP                      mpicxx -E
# [fclaw] CPPFLAGS
# [fclaw] F77                      mpif77
# [fclaw] FFLAGS                   -O2
# [fclaw] CC                       mpicxx
# [fclaw] CFLAGS                   -Wall -O2
# [fclaw] LIBS                     -lgomp   -lz
# [fclaw] This is ForestClaw 0.1.3876-132c8e-dirty
# [fclaw] CPP                      mpicxx -E
# [fclaw] CPPFLAGS
# [fclaw] F77                      mpif77
# [fclaw] FFLAGS                   -O2
# [fclaw] CC                       mpicxx
# [fclaw] CFLAGS                   -Wall -O2
# [fclaw] CXX                      mpicxx
# [fclaw[p4est] CC                       mpicxx
# [p4est] CFLAGS                   -Wall -O2
# [p4est] LDFLAGS
# [p4est] LIBS                     -lgomp   -lz
# [fclaw] This is ForestClaw 0.1.3876-132c8e-dirty
# [fclaw] CPP                      mpicxx -E
# [fclawfclaw] CFLAGS                   -Wall -O2
# [fclaw] CXX                      mpicxx
# [fclaw] CXXFLAGS                 -O2 -Wall
# [CXX                      mpicxx
# [fclaw] CXXFLAGS                 -O2 -Wall
# [fclaw] LDFLAGS
# [fclaw] FLIBS                     -L/opt/local/lib/mpich-gcc6 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0/../../.. -lmpifort -lmpi -lpmpi -lgfortran -lquadmath -lm
# [] CXXFLAGS                 -O2 -Wall
# [fclaw] LDFLAGS
# [fclaw] FLIBS                     -L/opt/local/lib/mpich-gcc6 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0/../../.. -lmpifort -lmpi -lpmpi -lgfortran -lquadmath -lm
# [fclaw] LIBS                     -lgomp   -lz
# ] CPPFLAGS
# [fclaw] F77                      mpif77
# [fclaw] FFLAGS                   -O2
# [fclaw] CC                       mpicxx
# fclaw] LDFLAGS
# [fclaw] FLIBS                     -L/opt/local/lib/mpich-gcc6 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0/../../.. -lmpifort -lmpi -lpmpi -lgfortran -lquadmath -lm
# [fclaw] LIBS                     -lgomp   -lz
# fclaw] LIBS                     -lgomp   -lz
# [fclaw] CFLAGS                   -Wall -O2
# [fclaw] CXX                      mpicxx
# [fclaw] CXXFLAGS                 -O2 -Wall
# [fclaw] LDFLAGS
# [fclaw] FLIBS                     -L/opt/local/lib/mpich-gcc6 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0 -L/opt/local/lib/gcc6/gcc/x86_64-apple-darwin17/6.4.0/../../.. -lmpifort -lmpi -lpmpi -lgfortran -lquadmath -lm
# [fclaw] LIBS                     -lgomp   -lz
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Options:
# [fclaw[fclaw] Options:
# [fclaw]    help                                 false
# [fclaw] Options:
# [fclaw]    help                                 false
# ]    help                                 false
# [fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw[fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw]    verbosity                            essential
# [fclaw[fclaw] Options:
# [fclaw]    help                                 false
# [fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw]    verbosity                            essential
# [fclaw]    lib-verbosity                        essential
# [fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw]    verbosity                            essential
# [fclaw]    lib-verbosity                        essential
# [fclaw]    verbosity                            essential
# [fclaw]    lib-verbosity                        essential
# [fclaw]    initial_dt                           0.005
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               4
# [fclaw]    nout                                 16
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     true
# [fclaw]    outstyle-uses-maxlevel               true
# []    lib-verbosity                        essential
# [fclaw]    initial_dt                           0.005
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               4
# [fclaw]    nout                                 16
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     true
# [fclaw]    outstyle-uses-maxlevel               true
# [fclaw]    subcycle                             true
# [fclaw]    weighted_partition                   false
# [[fclaw]    initial_dt                           0.005
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               4
# [fclaw]    nout                                 16
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     true
# [fclaw]    outstyle-uses-maxlevel               true
# [fclaw]    subcycle                             true
# ]    initial_dt                           0.005
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               4
# [fclaw]    nout                                 16
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     true
# [fclaw]    outstyle-uses-maxlevel               true
# [fclaw]    subcycle                             true
# [fclaw]    weighted_partition                   false
# [fclaw]    subcycle                             true
# [fclaw]    weighted_partition                   false
# [fclaw]    output                               true
# fclaw]    output                               true
# [fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         4 4
# [fclaw]    tikz-plot-prefix                     plot
# [fclaw]    weighted_partition                   false
# [fclaw]    output                               true
# [fclaw]    output                               true
# [fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         4 4
# [[fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         4 4
# [fclaw]    tikz-plot-prefix                     plot
# [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             2
# [fclaw]    maxlevel                             6
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         0
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.25
# [fclaw]    coarsen_threshold                    0.05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check       [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             2
# [fclaw]    maxlevel                             6
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         0
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.25
# [fclaw]    coarsen_threshold                    0.05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check                   false
# [fclaw]    report-timing                        true
# [fclaw]    ghost_patch_pack_area                true
# [fclaw]    ghost_patch_pack_extra  fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         4 4
# [fclaw]    tikz-plot-prefix                     plot
# [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             2
# [fclaw]    maxlevel                             6
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         0
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.25
# [fclaw]    coarsen_threshold                    0.05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check        fclaw]    tikz-plot-prefix                     plot
# [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             2
# [fclaw]    maxlevel                             6
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         0
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.25
# [fclaw]    coarsen_threshold                    0.05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check                   false
# [fclaw]    report-timing                        true
# [fclaw]    ghost_patch_pack_area                false
# [fclaw]    report-timing                        true
# [fclaw]    ghost_patch_pack_area                true
# [fclaw]    ghost_patch_pack_extra               false
# [fclaw]    ghost_patch_pack_numextrafields      0
# [fclaw]    trapfpe                              true
# [fclaw]              false
# [fclaw]    ghost_patch_pack_numextrafields      0
# [fclaw]    trapfpe                              true
# [fclaw]    mpi_debug                            false
# [fclaw]    ax                                   0
#            false
# [fclaw]    report-timing                        true
# [fclaw]    ghost_patch_pack_area                true
# [fclaw]    ghost_patch_pack_extra               false
#             true
# [fclaw]    ghost_patch_pack_extra               false
# [fclaw]    ghost_patch_pack_numextrafields      0
# [fclaw]    trapfpe                              true
#    mpi_debug                            false
# [fclaw]    ax                                   0
# [fclaw]    bx                                   1
# [fclaw]    ay                                   0
# [fclaw]    by                                   1
# [fclaw]    bx                                   1
# [fclaw]    ay                                   0
# [fclaw]    by                                   1
# [fclaw] [fclaw]    ghost_patch_pack_numextrafields      0
# [fclaw]    trapfpe                              true
# [fclaw]    mpi_debug                            false
# [fclaw] [fclaw]    mpi_debug                            false
# [fclaw]    ax                                   0
# [fclaw]    bx                                   1
# [fclaw] [fclaw]    manifold                             false
# [fclaw]    mi                                   1
# [fclaw]    mj                                   1
# [fclaw]    periodic_x                           false
# [fclaw]    periodic_y                           false
# [   manifold                             false
# [fclaw]    mi                                   1
# [fclaw]    mj                                   1
# [fclaw]    periodic_x                           false
# [fclaw   ax                                   0
# [fclaw]    bx                                   1
# [fclaw]    ay                                   0
# [fclaw]    by                                   1
# [   ay                                   0
# [fclaw]    by                                   1
# [fclaw]    manifold                             false
# [fclaw]    mi                                   1
# [fclawfclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         8
# [fclaw]    clawpatch:my                         8
# [fclaw]    clawpatch:maux                       3
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       true
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     0
# [fclaw]    clawpack46:src_term                  false
# [fclaw]    clawpack46:use-fwaves                false
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [fclaw]    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 true
# [fclaw]    clawpack46:vtk-out                ]    periodic_y                           false
# [fclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         8
# [fclaw]    clawpatch:my                         8
# [fclaw]    clawpatch:maux                       3
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       true
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     0
# [fclaw]    clawpack46:src_term                  false
# [fclaw]    clawpack46:use-fwaves                false
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [fclaw]    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 tfclaw]    manifold                             false
# [fclaw]    mi                                   1
# [fclaw]    mj                                   1
# [fclaw]    periodic_x                           false
# [fclaw]    periodic_y                           false
# [fclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         8
# [fclaw]    clawpatch:my                         8
# [fclaw]    clawpatch:maux                       3
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       true
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     0
# [fclaw]    clawpack46:src_term                  false
# [fclaw]    clawpack46:use-fwaves              ]    mj                                   1
# [fclaw]    periodic_x                           false
# [fclaw]    periodic_y                           false
# [fclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         8
# [fclaw]    clawpatch:my                         8
# [fclaw]    clawpatch:maux                       3
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       true
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     0
# [fclaw]    clawpack46:src_term                  false
# [fclaw]    clawpack46:use-fwaves                false
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [   false
# [fclaw]    clawpack5:order                      2 2
# [fclaw] rue
# [fclaw]    clawpack46:vtk-out                   false
# [fclaw]    clawpack5:order                      2 2
# [fclaw]   false
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [fclawfclaw]    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 true
# []    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 true
# [fclaw]    clawpack46:vtk-out                   false
# [fclaw]    clawpack46:vtk-out                   false
# [fclaw]    clawpack5:order                      2 2
# [fclaw   clawpack5:mcapa                      0
# [fclaw]    clawpack5:src_term                   false
# [fclaw]    clawpack5:use_fwaves                 false
# [fclaw]    clawpack5:mcapa                      0
# [fclaw]    clawpack5:src_term                   false
# [fclaw]    clawpack5:use_fwaves                 false
# [fclaw]    clawpack5:mwaves                     1
# [fclaw]    clawpack5:mwaves                     1
# [fclaw]    clawpack5:mthlim                     3
# [fclaw   clawpack5:mthlim                     3
# [fclaw]    clawpack5:mthbc                      1 1 1 1
# [fclaw]    clawpack5:ascii-out                  true
# [fclawfclaw]    clawpack5:order                      2 2
# [fclaw]    clawpack5:mcapa                      0
# [fclaw]    clawpack5:src_term                   false
# [fclaw]    clawpack5:use_fwaves                 false
# ]    clawpack5:mcapa                      0
# [fclaw]    clawpack5:src_term                   false
# [fclaw]    clawpack5:use_fwaves                 false
# [fclaw]    clawpack5:mthbc                      1 1 1 1
# [fclaw]    clawpack5:ascii-out                  true
# [fclaw]    clawpack5:vtk-out                    false
# []    clawpack5:vtk-out                    false
# [fclaw]    user:period                          4
# [fclaw]    user:claw-version                    4
# [fclaw] Arguments: none
# [fclaw]    clawpack5:mwaves                     1
# [fclaw]    clawpack5:mthlim                     3
# [fclaw]    clawpack5:mthbc                      1 1 1 1
# [fclaw]    clawpack5:ascii-out                  true
# ]    clawpack5:mwaves                     1
# [fclaw]    clawpack5:mthlim                     3
# [fclaw]    clawpack5:mthbc                      1 1 1 1
# [fclaw]    user:period                          4
# [fclaw]    user:claw-version                    4
# [fclaw] Arguments: none
# [fclaw]    clawpack5:vtk-out                    false
# [fclaw]    user:period                          4
# [fclawfclaw]    clawpack5:ascii-out                  true
# [fclaw]    clawpack5:vtk-out                    false
# [fclaw]    user:period                          4
# [fclaw]    user:claw-version                    4
# [fclaw] Arguments: none
# ]    user:claw-version                    4
# [fclaw] Arguments: none
# [p4est 0] Local minimum/maximum levels:  2  2
# [[p4est 0] Local minimum/maximum levels:  2  2
# [p4est] [p4est 0] Local minimum/maximum levels:  2  2
# [p4est] Global minimum/maximum levels:  2  2
# [[p4est 0] Local minimum/maximum levels:  2  2
# [p4est] Global minimum/maximum levels:  2  2
# [p4est 0] Patches on level  2:        16
# p4est] Global minimum/maximum levels:  2  2
# [p4est 0] Patches on level  2:        16
# Global minimum/maximum levels:  2  2
# [p4est 0] Patches on level  2:        16
# p4est 0] Patches on level  2:        16
# [fclaw] Max threads set to 0
# [fclaw] Max threads set to 0
# [fclaw] Max threads set to 0
# [fclaw] Max threads set to 0
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Output Frame    1  at time   2.50000000e-01
#
# [fclaw] Output Frame    1  at time   2.50000000e-01
#
# [fclaw] Output Frame    1  at time   2.50000000e-01
#
# [fclaw] Output Frame    1  at time   2.50000000e-01
#
# [fclaw] Output Frame    2  at time   5.00000000e-01
#
# [fclaw] Output Frame    2  at time   5.00000000e-01
#
# [fclaw] Output Frame    2  at time   5.00000000e-01
#
# [fclaw] Output Frame    2  at time   5.00000000e-01
#
# [fclaw] Output Frame    3  at time   7.50000000e-01
#
# [fclaw] Output Frame    3  at time   7.50000000e-01
#
# [fclaw] Output Frame    3  at time   7.50000000e-01
#
# [fclaw] Output Frame    3  at time   7.50000000e-01
#
# [fclaw] Output Frame    4  at time   1.00000000e+00
#
# [fclaw] Output Frame    4  at time   1.00000000e+00
#
# [fclaw] Output Frame    4  at time   1.00000000e+00
#
# [fclaw] Output Frame    4  at time   1.00000000e+00
#
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw] Output Frame    5  at time   1.25000000e+00
#
# [fclaw] Output Frame    5  at time   1.25000000e+00
#
# [fclaw] Output Frame    5  at time   1.25000000e+00
#
# [fclaw] Output Frame    5  at time   1.25000000e+00
#
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw] Output Frame    6  at time   1.50000000e+00
#
# [fclaw] Output Frame    6  at time   1.50000000e+00
#
# [fclaw] Output Frame    6  at time   1.50000000e+00
#
# [fclaw] Output Frame    6  at time   1.50000000e+00
#
# [fclaw] Output Frame    7  at time   1.75000000e+00
#
# [fclaw] Output Frame    7  at time   1.75000000e+00
#
# [fclaw] Output Frame    7  at time   1.75000000e+00
#
# [fclaw] Output Frame    7  at time   1.75000000e+00
#
# [fclaw] Output Frame    8  at time   2.00000000e+00
#
# [fclaw] Output Frame    8  at time   2.00000000e+00
#
# [fclaw] Output Frame    8  at time   2.00000000e+00
#
# [fclaw] Output Frame    8  at time   2.00000000e+00
#
# [fclaw] Output Frame    9  at time   2.25000000e+00
#
# [fclaw] Output Frame    9  at time   2.25000000e+00
#
# [fclaw] Output Frame    9  at time   2.25000000e+00
#
# [fclaw] Output Frame    9  at time   2.25000000e+00
#
# [fclaw] Output Frame   10  at time   2.50000000e+00
#
# [fclaw] Output Frame   10  at time   2.50000000e+00
#
# [fclaw] Output Frame   10  at time   2.50000000e+00
#
# [fclaw] Output Frame   10  at time   2.50000000e+00
#
# [fclaw] Output Frame   11  at time   2.75000000e+00
#
# [fclaw] Output Frame   11  at time   2.75000000e+00
#
# [fclaw] Output Frame   11  at time   2.75000000e+00
#
# [fclaw] Output Frame   11  at time   2.75000000e+00
#
# [fclaw] Output Frame   12  at time   3.00000000e+00
#
# [fclaw] Output Frame   12  at time   3.00000000e+00
#
# [fclaw] Output Frame   12  at time   3.00000000e+00
#
# [fclaw] Output Frame   12  at time   3.00000000e+00
#
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw] Output Frame   13  at time   3.25000000e+00
#
# [fclaw] Output Frame   13  at time   3.25000000e+00
#
# [fclaw] Output Frame   13  at time   3.25000000e+00
#
# [fclaw] Output Frame   13  at time   3.25000000e+00
#
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw] Output Frame   14  at time   3.50000000e+00
#
# [fclaw] Output Frame   14  at time   3.50000000e+00
#
# [fclaw] Output Frame   14  at time   3.50000000e+00
#
# [fclaw] Output Frame   14  at time   3.50000000e+00
#
# [fclaw] Output Frame   15  at time   3.75000000e+00
#
# [fclaw] Output Frame   15  at time   3.75000000e+00
#
# [fclaw] Output Frame   15  at time   3.75000000e+00
#
# [fclaw] Output Frame   15  at time   3.75000000e+00
#
# [fclaw] Output Frame   16  at time   4.00000000e+00
#
# [fclaw] Output Frame   16  at time   4.00000000e+00
#
# [fclaw] Output Frame   16  at time   4.00000000e+00
#
# [fclaw] Finalizing run
# [libsc] Statistics for INIT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0370549 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0370549
# [libsc]    Maximum attained at rank     0: 0.0370549
# [libsc] Statistics for ADVANCE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         156.733 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 156.733
# [libsc]    Maximum attained at rank     0: 156.733
# [libsc] Statistics for GHOSTFILL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.8103 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.8103
# [libsc]    Maximum attained at rank     0: 12.8103
# [libsc] Statistics for REGRID
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.561836 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.561836
# [libsc]    Maximum attained at rank     0: 0.561836
# [libsc] Statistics for DIAGNOSTICS
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         3.38415e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 3.38415e-05
# [libsc]    Maximum attained at rank     0: 3.38415e-05
# [libsc] Statistics for OUTPUT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         4.8017 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 4.8017
# [libsc]    Maximum attained at rank     0: 4.8017
# [libsc] Statistics for GHOSTPATCH_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00974024 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00974024
# [libsc]    Maximum attained at rank     0: 0.00974024
# [libsc] Statistics for ADAPT_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.58779 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.58779
# [libsc]    Maximum attained at rank     0: 1.58779
# [libsc] Statistics for PARTITION_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0073135 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0073135
# [libsc]    Maximum attained at rank     0: 0.0073135
# [libsc] Statistics for DIAGNOSTICS_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.00688e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.00688e-05
# [libsc]    Maximum attained at rank     0: 1.00688e-05
# [libsc] Statistics for CFL_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000491127 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000491127
# [libsc]    Maximum attained at rank     0: 0.000491127
# [libsc] Statistics for WALLTIME
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         176.602 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 176.602
# [libsc]    Maximum attained at rank     0: 176.602
# [libsc] Statistics for UNACCOUNTED
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0526368 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0526368
# [libsc]    Maximum attained at rank     0: 0.0526368
# [libsc] Statistics for ADVANCE_STEPS_COUNTER
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.2741e+06 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.2741e+06
# [libsc]    Maximum attained at rank     0: 2.2741e+06
# [libsc] Statistics for ADVANCE_STEPS_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         4.39734e-07 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 4.39734e-07
# [libsc]    Maximum attained at rank     0: 4.39734e-07
# [libsc] Statistics for GRIDS_PER_PROC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_PER_PROC_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000693001 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000693001
# [libsc]    Maximum attained at rank     0: 0.000693001
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_INTERIOR
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for REGRID_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.299787 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.299787
# [libsc]    Maximum attained at rank     0: 0.299787
# [libsc] Statistics for REGRID_TAGGING
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.187024 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.187024
# [libsc]    Maximum attained at rank     0: 0.187024
# [libsc] Statistics for GHOSTPATCH_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00476588 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00476588
# [libsc]    Maximum attained at rank     0: 0.00476588
# [libsc] Statistics for PARTITION
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0877019 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0877019
# [libsc]    Maximum attained at rank     0: 0.0877019
# [libsc] Statistics for PARTITION_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0807234 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0807234
# [libsc]    Maximum attained at rank     0: 0.0807234
# [libsc] Statistics for GHOSTFILL_COPY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         8.58252 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 8.58252
# [libsc]    Maximum attained at rank     0: 8.58252
# [libsc] Statistics for GHOSTFILL_AVERAGE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.47069 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.47069
# [libsc]    Maximum attained at rank     0: 1.47069
# [libsc] Statistics for GHOSTFILL_INTERP
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.03533 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.03533
# [libsc]    Maximum attained at rank     0: 2.03533
# [libsc] Statistics for GHOSTFILL_PHYSBC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.713965 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.713965
# [libsc]    Maximum attained at rank     0: 0.713965
# [libsc] Statistics for GHOSTFILL_STEP1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0701284 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0701284
# [libsc]    Maximum attained at rank     0: 0.0701284
# [libsc] Statistics for GHOSTFILL_STEP2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.3203 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.3203
# [libsc]    Maximum attained at rank     0: 12.3203
# [libsc] Statistics for GHOSTFILL_STEP3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.413691 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.413691
# [libsc]    Maximum attained at rank     0: 0.413691
# [libsc] Statistics for NEIGHBOR_SEARCH
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.67659 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.67659
# [libsc]    Maximum attained at rank     0: 1.67659
# [libsc] Statistics for FCLAW2D_TIMER_LOCAL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         174.996 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 174.996
# [libsc]    Maximum attained at rank     0: 174.996
# [libsc] Statistics for FCLAW2D_TIMER_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.60535 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.60535
# [libsc]    Maximum attained at rank     0: 1.60535
# [libsc] Statistics for EXTRA1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.124344 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.124344
# [libsc]    Maximum attained at rank     0: 0.124344
# [libsc] Statistics for EXTRA2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA4
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Procs 1 advance 117 156.733 exchange 1978 12.8103 regrid 107 106 0.561836
# [libsc] Max/P 1 advance 117 156.733 exchange 1978 12.8103 regrid 107 106 0.561836
# [fclaw] Finalizing run
# [libsc] Statistics for INIT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0389883 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0389883
# [libsc]    Maximum attained at rank     0: 0.0389883
# [libsc] Statistics for ADVANCE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         156.678 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 156.678
# [libsc]    Maximum attained at rank     0: 156.678
# [libsc] Statistics for GHOSTFILL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.8386 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.8386
# [libsc]    Maximum attained at rank     0: 12.8386
# [libsc] Statistics for REGRID
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.55887 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.55887
# [libsc]    Maximum attained at rank     0: 0.55887
# [libsc] Statistics for DIAGNOSTICS
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.87503e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.87503e-05
# [libsc]    Maximum attained at rank     0: 2.87503e-05
# [libsc] Statistics for OUTPUT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         4.87036 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 4.87036
# [libsc]    Maximum attained at rank     0: 4.87036
# [libsc] Statistics for GHOSTPATCH_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00910489 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00910489
# [libsc]    Maximum attained at rank     0: 0.00910489
# [libsc] Statistics for ADAPT_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.60047 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.60047
# [libsc]    Maximum attained at rank     0: 1.60047
# [libsc] Statistics for PARTITION_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00713917 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00713917
# [libsc]    Maximum attained at rank     0: 0.00713917
# [libsc] Statistics for DIAGNOSTICS_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.08443e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.08443e-05
# [libsc]    Maximum attained at rank     0: 1.08443e-05
# [libsc] Statistics for CFL_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000461833 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000461833
# [libsc]    Maximum attained at rank     0: 0.000461833
# [libsc] Statistics for WALLTIME
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         176.656 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 176.656
# [libsc]    Maximum attained at rank     0: 176.656
# [libsc] Statistics for UNACCOUNTED
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0545428 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0545428
# [libsc]    Maximum attained at rank     0: 0.0545428
# [libsc] Statistics for ADVANCE_STEPS_COUNTER
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.2741e+06 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.2741e+06
# [libsc]    Maximum attained at rank     0: 2.2741e+06
# [libsc] Statistics for ADVANCE_STEPS_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         4.39734e-07 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 4.39734e-07
# [libsc]    Maximum attained at rank     0: 4.39734e-07
# [libsc] Statistics for GRIDS_PER_PROC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_PER_PROC_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000693001 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000693001
# [libsc]    Maximum attained at rank     0: 0.000693001
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_INTERIOR
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for REGRID_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.297297 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.297297
# [libsc]    Maximum attained at rank     0: 0.297297
# [libsc] Statistics for REGRID_TAGGING
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.191111 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.191111
# [libsc]    Maximum attained at rank     0: 0.191111
# [libsc] Statistics for GHOSTPATCH_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00474932 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00474932
# [libsc]    Maximum attained at rank     0: 0.00474932
# [libsc] Statistics for PARTITION
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0861067 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0861067
# [libsc]    Maximum attained at rank     0: 0.0861067
# [libsc] Statistics for PARTITION_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0791088 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0791088
# [libsc]    Maximum attained at rank     0: 0.0791088
# [libsc] Statistics for GHOSTFILL_COPY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         8.58834 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 8.58834
# [libsc]    Maximum attained at rank     0: 8.58834
# [libsc] Statistics for GHOSTFILL_AVERAGE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.46946 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.46946
# [libsc]    Maximum attained at rank     0: 1.46946
# [libsc] Statistics for GHOSTFILL_INTERP
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.05039 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.05039
# [libsc]    Maximum attained at rank     0: 2.05039
# [libsc] Statistics for GHOSTFILL_PHYSBC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.722558 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.722558
# [libsc]    Maximum attained at rank     0: 0.722558
# [libsc] Statistics for GHOSTFILL_STEP1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0698814 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0698814
# [libsc]    Maximum attained at rank     0: 0.0698814
# [libsc] Statistics for GHOSTFILL_STEP2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.3412 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.3412
# [libsc]    Maximum attained at rank     0: 12.3412
# [libsc] Statistics for GHOSTFILL_STEP3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.421275 (0 = 0%)
# ...
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_INTERIOR
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for REGRID_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.308042 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.308042
# [libsc]    Maximum attained at rank     0: 0.308042
# [libsc] Statistics for REGRID_TAGGING
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.18537 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.18537
# [libsc]    Maximum attained at rank     0: 0.18537
# [libsc] Statistics for GHOSTPATCH_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00483539 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00483539
# [libsc]    Maximum attained at rank     0: 0.00483539
# [libsc] Statistics for PARTITION
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0889246 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0889246
# [libsc]    Maximum attained at rank     0: 0.0889246
# [libsc] Statistics for PARTITION_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0818477 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0818477
# [libsc]    Maximum attained at rank     0: 0.0818477
# [libsc] Statistics for GHOSTFILL_COPY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         8.60806 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 8.60806
# [libsc]    Maximum attained at rank     0: 8.60806
# [libsc] Statistics for GHOSTFILL_AVERAGE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.46922 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.46922
# [libsc]    Maximum attained at rank     0: 1.46922
# [libsc] Statistics for GHOSTFILL_INTERP
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.04611 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.04611
# [libsc]    Maximum attained at rank     0: 2.04611
# [libsc] Statistics for GHOSTFILL_PHYSBC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.721553 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.721553
# [libsc]    Maximum attained at rank     0: 0.721553
# [libsc] Statistics for GHOSTFILL_STEP1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0708748 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0708748
# [libsc]    Maximum attained at rank     0: 0.0708748
# [libsc] Statistics for GHOSTFILL_STEP2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.3543 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.3543
# [libsc]    Maximum attained at rank     0: 12.3543
# [libsc] Statistics for GHOSTFILL_STEP3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.421415 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.421415
# [libsc]    Maximum attained at rank     0: 0.421415
# [libsc] Statistics for NEIGHBOR_SEARCH
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.68964 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.68964
# [libsc]    Maximum attained at rank     0: 1.68964
# [libsc] Statistics for FCLAW2D_TIMER_LOCAL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         175.06 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 175.06
# [libsc]    Maximum attained at rank     0: 175.06
# [libsc] Statistics for FCLAW2D_TIMER_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.62804 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.62804
# [libsc]    Maximum attained at rank     0: 1.62804
# [libsc] Statistics for EXTRA1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.124781 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.124781
# [libsc]    Maximum attained at rank     0: 0.124781
# [libsc] Statistics for EXTRA2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA4
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Procs 1 advance 117 156.867 exchange 1978 12.8528 regrid 107 106 0.568073
# [libsc] Max/P 1 advance 117 156.867 exchange 1978 12.8528 regrid 107 106 0.568073
# [fclaw] Output Frame   16  at time   4.00000000e+00
#
# [fclaw] Finalizing run
# [libsc] Statistics for INIT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0394047 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0394047
# [libsc]    Maximum attained at rank     0: 0.0394047
# [libsc] Statistics for ADVANCE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         156.856 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 156.856
# [libsc]    Maximum attained at rank     0: 156.856
# [libsc] Statistics for GHOSTFILL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.8186 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.8186
# [libsc]    Maximum attained at rank     0: 12.8186
# [libsc] Statistics for REGRID
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.553552 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.553552
# [libsc]    Maximum attained at rank     0: 0.553552
# [libsc] Statistics for DIAGNOSTICS
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         3.2338e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 3.2338e-05
# [libsc]    Maximum attained at rank     0: 3.2338e-05
# [libsc] Statistics for OUTPUT
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         5.35844 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 5.35844
# [libsc]    Maximum attained at rank     0: 5.35844
# [libsc] Statistics for GHOSTPATCH_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0091113 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0091113
# [libsc]    Maximum attained at rank     0: 0.0091113
# [libsc] Statistics for ADAPT_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.61595 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.61595
# [libsc]    Maximum attained at rank     0: 1.61595
# [libsc] Statistics for PARTITION_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00692143 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00692143
# [libsc]    Maximum attained at rank     0: 0.00692143
# [libsc] Statistics for DIAGNOSTICS_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.17693e-05 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.17693e-05
# [libsc]    Maximum attained at rank     0: 1.17693e-05
# [libsc] Statistics for CFL_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000527119 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000527119
# [libsc]    Maximum attained at rank     0: 0.000527119
# [libsc] Statistics for WALLTIME
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         177.311 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 177.311
# [libsc]    Maximum attained at rank     0: 177.311
# [libsc] Statistics for UNACCOUNTED
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0526433 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0526433
# [libsc]    Maximum attained at rank     0: 0.0526433
# [libsc] Statistics for ADVANCE_STEPS_COUNTER
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.2741e+06 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.2741e+06
# [libsc]    Maximum attained at rank     0: 2.2741e+06
# [libsc] Statistics for ADVANCE_STEPS_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         4.39734e-07 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 4.39734e-07
# [libsc]    Maximum attained at rank     0: 4.39734e-07
# [libsc] Statistics for GRIDS_PER_PROC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_PER_PROC_INV_HMEAN
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.000693001 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.000693001
# [libsc]    Maximum attained at rank     0: 0.000693001
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_INTERIOR
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_LOCAL_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for GRIDS_REMOTE_BOUNDARY_RATIO
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1443
# [libsc]    Maximum attained at rank     0: 1443
# [libsc] Statistics for REGRID_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.296301 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.296301
# [libsc]    Maximum attained at rank     0: 0.296301
# [libsc] Statistics for REGRID_TAGGING
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.190835 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.190835
# [libsc]    Maximum attained at rank     0: 0.190835
# [libsc] Statistics for GHOSTPATCH_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.00477024 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.00477024
# [libsc]    Maximum attained at rank     0: 0.00477024
# [libsc] Statistics for PARTITION
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0828568 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0828568
# [libsc]    Maximum attained at rank     0: 0.0828568
# [libsc] Statistics for PARTITION_BUILD
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.0760443 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.0760443
# [libsc]    Maximum attained at rank     0: 0.0760443
# [libsc] Statistics for GHOSTFILL_COPY
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         8.57005 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 8.57005
# [libsc]    Maximum attained at rank     0: 8.57005
# [libsc] Statistics for GHOSTFILL_AVERAGE
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.47354 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.47354
# [libsc]    Maximum attained at rank     0: 1.47354
# [libsc] Statistics for GHOSTFILL_INTERP
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         2.04834 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 2.04834
# [libsc]    Maximum attained at rank     0: 2.04834
# [libsc] Statistics for GHOSTFILL_PHYSBC
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.718935 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.718935
# [libsc]    Maximum attained at rank     0: 0.718935
# [libsc] Statistics for GHOSTFILL_STEP1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.070518 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.070518
# [libsc]    Maximum attained at rank     0: 0.070518
# [libsc] Statistics for GHOSTFILL_STEP2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         12.3232 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 12.3232
# [libsc]    Maximum attained at rank     0: 12.3232
# [libsc] Statistics for GHOSTFILL_STEP3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.418788 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.418788
# [libsc]    Maximum attained at rank     0: 0.418788
# [libsc] Statistics for NEIGHBOR_SEARCH
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.72362 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.72362
# [libsc]    Maximum attained at rank     0: 1.72362
# [libsc] Statistics for FCLAW2D_TIMER_LOCAL
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         175.679 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 175.679
# [libsc]    Maximum attained at rank     0: 175.679
# [libsc] Statistics for FCLAW2D_TIMER_COMM
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         1.63252 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 1.63252
# [libsc]    Maximum attained at rank     0: 1.63252
# [libsc] Statistics for EXTRA1
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0.126069 (0 = 0%)
# [libsc]    Minimum attained at rank     0: 0.126069
# [libsc]    Maximum attained at rank     0: 0.126069
# [libsc] Statistics for EXTRA2
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA3
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Statistics for EXTRA4
# [libsc]    Global number of values:     1
# [libsc]    Mean value (std. dev.):         0 (0)
# [libsc]    Minimum attained at rank     0: 0
# [libsc]    Maximum attained at rank     0: 0
# [libsc] Procs 1 advance 117 156.856 exchange 1978 12.8186 regrid 107 106 0.553552
# [libsc] Max/P 1 advance 117 156.856 exchange 1978 12.8186 regrid 107 106 0.553552

# %% [markdown]
# ---
# Create PNG files for web-browser viewing, or animation.

# %%
# %run make_plots.py

# %% [markdown]
# ---
# View PNG files in browser, using URL above, or create an animation of all PNG files, using code below.

# %%
# %pylab inline

# %%
import glob
from matplotlib import image
from clawpack.visclaw.JSAnimation import IPython_display
from matplotlib import animation

figno = 0
fname = '_plots/*fig' + str(figno) + '.png'
filenames=sorted(glob.glob(fname))

fig = plt.figure()
im = plt.imshow(image.imread(filenames[0]))
def init():
    im.set_data(image.imread(filenames[0]))
    return im,

def animate(i):
    image_i=image.imread(filenames[i])
    im.set_data(image_i)
    return im,

animation.FuncAnimation(fig, animate, init_func=init,
                              frames=len(filenames), interval=500, blit=True)

# %% [markdown]
# ---
